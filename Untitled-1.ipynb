# %%
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api.formatters import JSONFormatter
import json
xyz = YouTubeTranscriptApi().fetch('8iuLXODzL04', languages=['ja'])
json_formatted = json.loads(JSONFormatter().format_transcript(xyz))
print(json_formatted)
# Out:
# [{'text': '涙流すことすら無いまま\nnamida nagasu koto sura nai mama', 'start': 6.4, 'duration': 5.3}, {'text': '過ごした⽇々の痕⼀つも残さずに\nsugoshita hibi no ato hitotsu mo nokosazu ni', 'start': 11.7, 'duration': 8.4}, {'text': 'さよならだ\nsayonara da', 'start': 21.0, 'duration': 3.6}, {'text': '⼀⼈で迎えた朝に\nhitori de mukaeta asa ni', 'start': 27.8, 'duration': 2.4}, {'text': '鳴り響く誰かの⾳\nnarihibiku dareka no oto', 'start': 30.6, 'duration': 2.4}, {'text': '⼆⼈で過ごした部屋で\nfutari de sugoshita heya de', 'start': 33.3, 'duration': 2.3}, {'text': '⽬を閉じたまま考えてた\nme wo tojita mama kangaeteta', 'start': 35.9, 'duration': 2.7}, {'text': '悪いのは誰だ\nwarui no wa dare da', 'start': 38.6, 'duration': 3.3}, {'text': '分かんないよ\nwakannai yo', 'start': 42.3, 'duration': 1.6}, {'text': '誰のせいでもない\ndare no sei demo nai', 'start': 44.0, 'duration': 3.1}, {'text': 'たぶん\ntabun', 'start': 47.4, 'duration': 1.2}, {'text': '僕らは何回だってきっと\nbokura wa nankai datte kitto', 'start': 48.6, 'duration': 3.1}, {'text': 'そう何年だってきっと\nsou nannen datte kitto', 'start': 51.7, 'duration': 2.5}, {'text': 'さよならと共に終わるだけなんだ\nsayonara to tomo ni owaru dake nan da', 'start': 54.2, 'duration': 5.5}, {'text': '仕⽅がないよきっと\nshikata ga nai yo kitto', 'start': 59.7, 'duration': 2.5}, {'text': '「おかえり」\n“okaeri”', 'start': 62.2, 'duration': 0.92}, {'text': '思わず零れた⾔葉は\nomowazu koboreta kotoba wa', 'start': 63.12, 'duration': 3.78}, {'text': '違うな\nchigau na', 'start': 66.9, 'duration': 3.1}, {'text': '⼀⼈で迎えた朝に\nhitori de mukaeta asa ni', 'start': 78.6, 'duration': 2.26}, {'text': 'ふと想う誰かのこと\nfuto omou dareka no koto', 'start': 81.2, 'duration': 2.2}, {'text': '⼆⼈で過ごした⽇々の\nfutari de sugoshita hibi no', 'start': 83.9, 'duration': 2.1}, {'text': '当たり前がまだ残っている\natarimae ga mada nokotteiru', 'start': 86.6, 'duration': 2.6}, {'text': '悪いのは君だ\nwarui no wa kimi da', 'start': 89.2, 'duration': 3.3}, {'text': 'そうだっけ\nsou dakke', 'start': 92.8, 'duration': 1.52}, {'text': '悪いのは僕だ\nwarui no wa boku da', 'start': 94.6, 'duration': 3.2}, {'text': 'たぶん\ntabun', 'start': 98.0, 'duration': 1.4}, {'text': 'これも⼤衆的恋愛でしょ\nkore mo taishuuteki renai desho', 'start': 99.6, 'duration': 2.6}, {'text': 'それは最終的な答えだよ\nsore wa saishuuteki na kotae da yo', 'start': 102.2, 'duration': 2.6}, {'text': '僕らだんだんとズレていったの\nbokura dandan to zurete itta no', 'start': 104.8, 'duration': 2.72}, {'text': 'それもただよくある聴き慣れたストーリーだ\nsore mo tada yoku arukiki nareta sutoorii da', 'start': 107.52, 'duration': 3.18}, {'text': 'あんなに輝いていた⽇々にすら\nanna ni kagayaiteita hibi ni sura', 'start': 110.7, 'duration': 4.9}, {'text': '埃は積もっていくんだ\nhokori wa tsumotte ikun da', 'start': 115.6, 'duration': 3.76}, {'text': '僕らは何回だってきっと\nbokura wa nankai datte kitto', 'start': 120.0, 'duration': 3.6}, {'text': 'そう何年だってきっと\nsou nannen datte kitto', 'start': 123.6, 'duration': 2.6}, {'text': 'さよならに続く道を歩くんだ\nsayonara ni tsuzuku michi wo arukun da', 'start': 126.2, 'duration': 5.4}, {'text': '仕⽅がないよきっと\nshikata ga nai yo kitto', 'start': 131.6, 'duration': 2.4}, {'text': '「おかえり」\n“okaeri”', 'start': 134.0, 'duration': 1.2}, {'text': 'いつもの様に\nitsumo no you ni', 'start': 135.2, 'duration': 2.7}, {'text': '零れ落ちた\nkoboreochita', 'start': 137.9, 'duration': 5.68}, {'text': '分かり合えないことなんてさ\nwakariaenai koto nante sa', 'start': 158.6, 'duration': 2.2}, {'text': '幾らでもあるんだきっと\nikura demo arun da kitto', 'start': 160.8, 'duration': 2.5}, {'text': '全てを許し合えるわけじゃないから\nsubete wo yurushiaeru wake janai kara', 'start': 163.3, 'duration': 5.5}, {'text': 'ただ、優しさの⽇々を\ntada, yasashisa no hibi wo', 'start': 168.8, 'duration': 2.34}, {'text': '⾟い⽇々と感じてしまったのなら\ntsurai hibi to kanjite shimatta no nara', 'start': 171.14, 'duration': 3.86}, {'text': '戻れないから\nmodorenai kara', 'start': 175.0, 'duration': 5.1}, {'text': '僕らは何回だってきっと\nbokura wa nankai datte kitto', 'start': 181.8, 'duration': 2.7}, {'text': '僕らは何回だってきっと\nbokura wa nankai datte kitto', 'start': 184.6, 'duration': 3.0}, {'text': 'そう何年だってきっと\nsou nannen datte kitto', 'start': 187.6, 'duration': 2.6}, {'text': 'さよならと共に終わるだけなんだ\nsayonara to tomo ni owaru dake nan da' ...

# %%
[x['text'].split('\n')[0] for x in json_formatted ]
# Out:
# ['涙流すことすら無いまま',
#  '過ごした⽇々の痕⼀つも残さずに',
#  'さよならだ',
#  '⼀⼈で迎えた朝に',
#  '鳴り響く誰かの⾳',
#  '⼆⼈で過ごした部屋で',
#  '⽬を閉じたまま考えてた',
#  '悪いのは誰だ',
#  '分かんないよ',
#  '誰のせいでもない',
#  'たぶん',
#  '僕らは何回だってきっと',
#  'そう何年だってきっと',
#  'さよならと共に終わるだけなんだ',
#  '仕⽅がないよきっと',
#  '「おかえり」',
#  '思わず零れた⾔葉は',
#  '違うな',
#  '⼀⼈で迎えた朝に',
#  'ふと想う誰かのこと',
#  '⼆⼈で過ごした⽇々の',
#  '当たり前がまだ残っている',
#  '悪いのは君だ',
#  'そうだっけ',
#  '悪いのは僕だ',
#  'たぶん',
#  'これも⼤衆的恋愛でしょ',
#  'それは最終的な答えだよ',
#  '僕らだんだんとズレていったの',
#  'それもただよくある聴き慣れたストーリーだ',
#  'あんなに輝いていた⽇々にすら',
#  '埃は積もっていくんだ',
#  '僕らは何回だってきっと',
#  'そう何年だってきっと',
#  'さよならに続く道を歩くんだ',
#  '仕⽅がないよきっと',
#  '「おかえり」',
#  'いつもの様に',
#  '零れ落ちた',
#  '分かり合えないことなんてさ',
#  '幾らでもあるんだきっと',
#  '全てを許し合えるわけじゃないから',
#  'ただ、優しさの⽇々を',
#  '⾟い⽇々と感じてしまったのなら',
#  '戻れないから',
#  '僕らは何回だってきっと',
#  '僕らは何回だってきっと',
#  'そう何年だってきっと',
#  'さよならと共に終わるだけなんだ',
#  '仕⽅がないよきっと',
#  '「おかえり」',
#  '思わず零れた⾔葉は',
#  '違うな',
#  'それでも何回だってきっと',
#  'そう何年だってきっと',
#  '始まりに戻ることが出来たなら',
#  'なんて、思ってしまうよ',
#  '「おかえり」',
#  '届かず零れた⾔葉に',
#  '笑った',
#  '少し冷えた朝だ',
#  'Music : Ayase',
#  'Vocal : ikura',
#  'Video : 南條沙歩',
#  '『たぶん』']

# %%
import json
json.loads(json_formatted)
